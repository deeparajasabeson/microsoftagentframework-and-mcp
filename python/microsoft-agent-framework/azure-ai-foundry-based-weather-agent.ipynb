# %%
# Copyright (c) Microsoft. All rights reserved.
"""Foundry-based weather agent for Agent Framework Debug UI.

This agent uses Azure AI Foundry with Azure CLI authentication.
Make sure to run 'az login' before starting devui.
"""
# Out:
# "Foundry-based weather agent for Agent Framework Debug UI.\n\nThis agent uses Azure AI Foundry with Azure CLI authentication.\nMake sure to run 'az login' before starting devui.\n"

# %%
import os
from typing import Annotated
from agent_framework import ChatAgent
from agent_framework.azure import AzureOpenAIChatClient
from pydantic import Field

# %%
def get_weather(
    location: Annotated[str, Field(description="The location to get the weather for.")],
) -> str:
    """Get the weather for a given location."""
    conditions = ["sunny", "cloudy", "rainy", "stormy"]
    temperature = 22
    return f"The weather in {location} is {conditions[0]} with a high of {temperature}°C."

# %%
def get_forecast(
    location: Annotated[str, Field(description="The location to get the forecast for.")],
    days: Annotated[int, Field(description="Number of days for forecast")] = 3,
) -> str:
    """Get weather forecast for multiple days."""
    conditions = ["sunny", "cloudy", "rainy", "stormy"]
    forecast: list[str] = []

    for day in range(1, days + 1):
        condition = conditions[day % len(conditions)]
        temp = 18 + day
        forecast.append(f"Day {day}: {condition}, {temp}°C")

    return f"Weather forecast for {location}:\n" + "\n".join(forecast)

# %%
# Agent instance following Agent Framework conventions
api_key = "Ab2GlJUSQYwxHFUNul6TMIodpXDGxRM7jMCGywlvv2DcTiHwE1J0JQQJ99BJACYeBjFXJ3w3AAABACOG8QKg"
endpoint = "https://agent-azureopenaiclient.openai.azure.com/"
deployment_name = "gpt-5-mini"

# Agent instance following Agent Framework conventions
agent = AzureOpenAIChatClient(
    api_key=api_key,
    endpoint=endpoint,
    deployment_name=deployment_name
).create_agent(
    name="FoundryWeatherAgent",
    description="An agent that answers questions about the weather.",
    instructions="""
    You are a weather assistant using Azure AI Foundry models. You can provide
    current weather information and forecasts for any location. Always be helpful
    and provide detailed weather information when asked.
    """,
    tools=[get_weather, get_forecast]
)

# %%
def main():
    """Launch the Foundry weather agent in DevUI."""
    import logging

    from agent_framework.devui import serve

    # Setup logging
    logging.basicConfig(level=logging.INFO, format="%(message)s")
    logger = logging.getLogger(__name__)

    logger.info("Starting Foundry Weather Agent")
    logger.info("Available at: http://localhost:8090")
    logger.info("Entity ID: agent_FoundryWeatherAgent")
    logger.info("Note: Make sure 'az login' has been run for authentication")

    # Launch server with the agent
    serve(entities=[agent], port=8090, auto_open=True)


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File c:\Deepa\Learning\AI-ML\.Net Core\microsoftagentframework-and-mcp\.venv\Lib\site-packages\uvicorn\_compat.py:23, in asyncio_run(main, debug, loop_factory)
#      22 with asyncio.Runner(debug=debug, loop_factory=loop_factory) as runner:
# ---> 23     return runner.run(main)
#
# File C:\Python311\Lib\asyncio\runners.py:93, in Runner.run(self, coro, context)
#      91 if events._get_running_loop() is not None:
#      92     # fail fast with short traceback
# ---> 93     raise RuntimeError(
#      94         "Runner.run() cannot be called from a running event loop")
#      96 self._lazy_init()
#
# RuntimeError: Runner.run() cannot be called from a running event loop
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 21
#      17     serve(entities=[agent], port=8090, auto_open=True)
#      20 if __name__ == "__main__":
# ---> 21     main()
#
# Cell In[8], line 17, in main()
#      14 logger.info("Note: Make sure 'az login' has been run for authentication")
#      16 # Launch server with the agent
# ---> 17 serve(entities=[agent], port=8090, auto_open=True)
#
# File c:\Deepa\Learning\AI-ML\.Net Core\microsoftagentframework-and-mcp\.venv\Lib\site-packages\agent_framework_devui\__init__.py:129, in serve(entities, entities_dir, port, host, auto_open, cors_origins, ui_enabled, tracing_enabled)
#     126     threading.Thread(target=open_browser, daemon=True).start()
#     128 logger.info(f"Starting Agent Framework DevUI on {host}:{port}")
# --> 129 uvicorn.run(app, host=host, port=port, log_level="info")
#
# File c:\Deepa\Learning\AI-ML\.Net Core\microsoftagentframework-and-mcp\.venv\Lib\site-packages\uvicorn\main.py:593, in run(app, host, port, uds, fd, loop, http, ws, ws_max_size, ws_max_queue, ws_ping_interval, ws_ping_timeout, ws_per_message_deflate, lifespan, interface, reload, reload_dirs, reload_includes, reload_excludes, reload_delay, workers, env_file, log_config, log_level, access_log, proxy_headers, server_header, date_header, forwarded_allow_ips, root_path, limit_concurrency, backlog, limit_max_requests, timeout_keep_alive, timeout_graceful_shutdown, timeout_worker_healthcheck, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_version, ssl_cert_reqs, ssl_ca_certs, ssl_ciphers, headers, use_colors, app_dir, factory, h11_max_incomplete_event_size)
#     591         Multiprocess(config, target=server.run, sockets=[sock]).run()
#     592     else:
# --> 593         server.run()
#     594 except KeyboardInterrupt:
#     595     pass  # pragma: full coverage
#
# File c:\Deepa\Learning\AI-ML\.Net Core\microsoftagentframework-and-mcp\.venv\Lib\site-packages\uvicorn\server.py:67, in Server.run(self, sockets)
#      66 def run(self, sockets: list[socket.socket] | None = None) -> None:
# ---> 67     return asyncio_run(self.serve(sockets=sockets), loop_factory=self.config.get_loop_factory())
#
# File c:\Deepa\Learning\AI-ML\.Net Core\microsoftagentframework-and-mcp\.venv\Lib\site-packages\uvicorn\_compat.py:22, in asyncio_run(main, debug, loop_factory)
#      14 def asyncio_run(
#      15     main: Coroutine[Any, Any, _T],
#      16     *,
#    (...)     20     # asyncio.run from Python 3.12
#      21     # https://docs.python.org/3/license.html#psf-license
# ---> 22     with asyncio.Runner(debug=debug, loop_factory=loop_factory) as runner:
#      23         return runner.run(main)
#
# File C:\Python311\Lib\asyncio\runners.py:63, in Runner.__exit__(self, exc_type, exc_val, exc_tb)
#      62 def __exit__(self, exc_type, exc_val, exc_tb):
# ---> 63     self.close()
#
# File C:\Python311\Lib\asyncio\runners.py:72, in Runner.close(self)
#      70     loop = self._loop
#      71     _cancel_all_tasks(loop)
# ---> 72     loop.run_until_complete(loop.shutdown_asyncgens())
#      73     loop.run_until_complete(loop.shutdown_default_executor())
#      74 finally:
#
# File C:\Python311\Lib\asyncio\base_events.py:626, in BaseEventLoop.run_until_complete(self, future)
#     615 """Run until the Future is done.
#     616
#     617 If the argument is a coroutine, it is wrapped in a Task.
#    (...)    623 Return the Future's result, or raise its exception.
#     624 """
#     625 self._check_closed()
# --> 626 self._check_running()
#     628 new_task = not futures.isfuture(future)
#     629 future = tasks.ensure_future(future, loop=self)
#
# File C:\Python311\Lib\asyncio\base_events.py:588, in BaseEventLoop._check_running(self)
#     586     raise RuntimeError('This event loop is already running')
#     587 if events._get_running_loop() is not None:
# --> 588     raise RuntimeError(
#     589         'Cannot run the event loop while another loop is running')
#
# RuntimeError: Cannot run the event loop while another loop is running
